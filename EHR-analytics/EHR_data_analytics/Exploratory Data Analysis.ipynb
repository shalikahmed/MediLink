# %%
import pandas as pd
import pandas_profiling
from dataprep.eda import *
import seaborn as sns

# %%
data = pd.read_csv('DUMMY_DATA.csv')

# %%
data.head()
# Out:
#    encounter_id  Hospital Death  Height  Weight         Ethnicity   Age  \
# 0         34937               1     NaN     NaN          Hispanic   NaN
# 1        483670               0     NaN     NaN             Asian  53.0
# 2        150725               1  175.14     NaN  African American   NaN
# 3        278547               0  183.08     NaN  African American   NaN
# 4        457468               0  162.62   73.88  African American  58.0
#
#   Gender  Diagnosis code  Albumin  Arterial_partial_pressure_co2  ...  \
# 0      M             NaN      NaN                           34.0  ...
# 1    NaN             NaN      NaN                           29.0  ...
# 2    NaN           249.0      1.0                            NaN  ...
# 3    NaN             NaN      6.0                           68.0  ...
# 4    NaN             NaN      6.0                          225.0  ...
#
#    Resprate_rate  Sodium  Oxygen_saturation  Temperature    WBC  Urineoutput  \
# ...

# %%
data.describe()
# Out:
#         encounter_id  Hospital Death      Height      Weight         Age  \
# count    1000.000000     1000.000000  339.000000  340.000000  330.000000
# mean   261509.747000        0.512000  160.843392   58.474588   55.887879
# std    136155.949042        0.500106   19.085316   19.817994   21.725061
# min     21283.000000        0.000000   99.980000    9.000000   16.000000
# 25%    140835.250000        0.000000  148.520000   43.460000   39.000000
# 50%    261756.500000        1.000000  160.440000   57.790000   56.000000
# 75%    374011.000000        1.000000  172.890000   72.032500   76.000000
# max    500031.000000        1.000000  221.190000  108.420000   89.000000
#
#        Diagnosis code     Albumin  Arterial_partial_pressure_co2  Arterial_ph  \
# count      488.000000  700.000000                     700.000000   700.000000
# mean       350.237705    3.472857                     129.000000     7.367143
# ...

# %%
sns.distplot(data['Hospital Death'],  color ='green', bins = 40) 
print("Skewness: %f" %data['Hospital Death'].skew())
print("Mean: %f" % data['Hospital Death'].mean())
print("Median: %f" % data['Hospital Death'].median())
print("Kurtosis: %f" % data['Hospital Death'].kurt())
# Out:
# Skewness: -0.048086
# Mean: 0.512000
# Median: 1.000000
# Kurtosis: -2.001695

# %%
data.columns
# Out:
# Index(['encounter_id', 'Hospital Death', 'Height', 'Weight', 'Ethnicity',
#        'Age', 'Gender', 'Diagnosis code', 'Albumin',
#        'Arterial_partial_pressure_co2', 'Arterial_ph', 'Bilirubin', 'BUN',
#        'Calcium', 'Creatinine', 'glucose', 'Hco3', 'heart_rate', 'Hemaglobin',
#        'Hematocrit', 'INR', 'Lactate', 'Mean_blood_pressure', 'Pao2fio2',
#        'Platlets', 'Potassium', 'Resprate_rate', 'Sodium', 'Oxygen_saturation',
#        'Temperature', 'WBC', 'Urineoutput', 'Systolic_blood_pressure_max',
#        'Systolic_blood_pressure_min', 'Diastolic_blood_pressure_min',
#        'Diastolic_blood_pressure_max'],
#       dtype='object')

# %%
sns.pairplot(data[['Height', 'Weight',
       'Age', 'Gender']], hue ="Gender")

# %%
data.hist(column ='Age', bins = 50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f96aa038400>]],
#       dtype=object)

# %%
data.hist(figsize=(30, 20), bins=50, xlabelsize=10, ylabelsize=10)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f96aa045080>,
# ...
#       dtype=object)

# %% [markdown]
# # dataprep.eda library for visualizations

# %%
plot(data)
# Out:
#
#
#
#
#
#             <div class="bk-root" id="686e3fac-f749-4e53-8c8e-25fc08a208e5" data-root-id="2369"></div>
#
#
#
#
#
#         <script type="application/json" id="4746">
# ...

# %%
plot(data, "Temperature")
# Out:
#
#
#
#
#
#             <div class="bk-root" id="39bdc2e6-3106-422e-8c65-3f6dee4244ea" data-root-id="4928"></div>
#
#
#
#
#
#         <script type="application/json" id="5303">
# ...

# %%
plot(data,"Ethnicity")
# Out:
#
#
#
#
#
#             <div class="bk-root" id="2bcf94fe-4297-41b1-a6e2-9ad9b373f64c" data-root-id="5481"></div>
#
#
#
#
#
#         <script type="application/json" id="5823">
# ...

# %%
plot(data, "Age", "Urineoutput")
# Out:
#
#
#
#
#
#             <div class="bk-root" id="459e3a4d-1c38-4b62-aa11-d1025a2349e9" data-root-id="5963"></div>
#
#
#
#
#
#         <script type="application/json" id="6276">
# ...

# %%
plot_correlation(data, x="Albumin", y="Sodium")
# Out:
#
#
#
#
#
#             <div class="bk-root" id="555b20ed-1857-4535-8ec8-bac5a964d93c" data-root-id="6278"></div>
#
#
#
#
#
#         <script type="application/json" id="6418">
# ...

# %%
plot_missing(data,"WBC", "Calcium")
# Out:
#
#
#
#
#
#             <div class="bk-root" id="42b5492f-a196-4e62-b964-db3a83c59977" data-root-id="6621"></div>
#
#
#
#
#
#         <script type="application/json" id="7174">
# ...

# %%
plot_missing(data,"Age", "Height")
# Out:
#
#
#
#
#
#             <div class="bk-root" id="aaf4ba43-8576-4c22-8900-43298500a387" data-root-id="7377"></div>
#
#
#
#
#
#         <script type="application/json" id="7930">
# ...

# %%
data.profile_report(style={'full_width':True})
profile = data.profile_report(title='Pandas Profiling Report dummy')
profile.to_file(output_file="report_dummy.json")
profile.to_file(output_file="report_dummy.html")
